# %%
df_nov = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv", header=True, inferSchema=True)

# %%
display(df_nov.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_nov.select("brand", "product_id", "price").show(10)
# Out:
# +--------+----------+------+
# |   brand|product_id| price|
# +--------+----------+------+
# |  xiaomi|   1003461|489.07|
# |  janome|   5000088|293.65|
# |   creed|  17302664| 28.31|
# |      lg|   3601530|712.87|
# |  xiaomi|   1004775|183.27|
# |      hp|   1306894|360.09|
# |      hp|   1306421|514.56|
# | rondell|  15900065| 30.86|
# |michelin|  12708937| 72.72|
# |   apple|   1004258|732.07|
# +--------+----------+------+
# only showing top 10 rows

# %%
df_nov.filter("price > 500").count()
# Out:
# 11444455

# %%
df_nov.groupBy("event_type").count().show()
# Out:
# +----------+--------+
# |event_type|   count|
# +----------+--------+
# |  purchase|  916939|
# |      cart| 3028930|
# |      view|63556110|
# +----------+--------+

# %%
top_brands = df_nov.groupBy("brand").count().orderBy("count", ascending=False).limit(5).show()
# Out:
# +-------+-------+
# |  brand|  count|
# +-------+-------+
# |   NULL|9218235|
# |samsung|7889245|
# |  apple|6259379|
# | xiaomi|4638062|
# | huawei|1410126|
# +-------+-------+
